# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2

# %%
# loading ipython sql
# %load_ext sql
# importing neecssary libraries
from sqlalchemy import create_engine
import datetime
from datetime import date
from datetime import time
import pandas as pd
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:password@localhost/moodle

# %%
# %sql SELECT count(*) FROM mdl_assign
# Out:
# * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# [(63,)]

# %% [markdown]
# # Task 1

# %% [markdown]
# Download the database and write an SQL script to count :
# Number of quiz submissions by hour of day
# -Monthly usage time of learners who have confirmed and are not deleted
# -Count of log events per user for the following verbs: ['loggedin', 'viewed', 'started', ,'submitted', 'uploaded', 'updated', 'searched', 'resumed', 'answered', 'attempted', 'abandoned']
# -Write a python class to pull
# -Overall grade of learners for
# -Number of forum posts

# %% [markdown]
# ## the number of tables

# %%
# %sql SELECT * FROM information_schema.tables;
# Out:
# * postgresql://postgres:***@localhost/moodle
# 642 rows affected.
# [('moodle', 'public', 'mdl_analytics_indicator_calc', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_models', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_models_log', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_predict_samples', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_prediction_actions', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_predictions', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('moodle', 'public', 'mdl_analytics_train_samples', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
# ...

# %% [markdown]
# ## the number of records in each of the tables given in the MIT section

# %%
def selectf(table):
    sql = %sql SELECT *FROM {table} limit 5
    sql = print(sql)
    return sql

# %%
tables = ('mdl_logstore_standard_log',
'mdl_context',
'mdl_user',
'mdl_course',
'mdl_modules', 
'mdl_course_modules',
'mdl_course_modules_completion', 
'mdl_grade_items',
'mdl_grade_grades',
'mdl_grade_categories',
'mdl_grade_items_history',
'mdl_grade_grades_history',
'mdl_grade_categories_history',
'mdl_forum',
'mdl_forum_discussions',
'mdl_forum_posts')


for table in tables:
    print(table)
    select(table)
# Out:
# mdl_logstore_standard_log
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +--------+
# | count  |
# +--------+
# | 417554 |
# +--------+
# mdl_context
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |  4359 |
# +-------+
# mdl_user
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |  1052 |
# +-------+
# mdl_course
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |   15  |
# +-------+
# mdl_modules
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |   26  |
# +-------+
# mdl_course_modules
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |  290  |
# +-------+
# mdl_course_modules_completion
#  * postgresql://postgres:***@localhost/moodle
# 1 rows affected.
# +-------+
# | count |
# ...

# %% [markdown]
# ## Number of quiz submissions by hour of day

# %%
for table in tables:
    print(table)
    select(table)
# Out:
# mdl_logstore_standard_log
#  * postgresql://postgres:***@localhost/moodle
# 5 rows affected.
# +----+------------------------------+-----------+----------+-----------+-------------+----------+------+----------+-----------+--------------+-------------------+--------+----------+---------------+-----------+-----------------------------------+-------------+--------+----------------+------------+
# | id |          eventname           | component |  action  |   target  | objecttable | objectid | crud | edulevel | contextid | contextlevel | contextinstanceid | userid | courseid | relateduserid | anonymous |               other               | timecreated | origin |       ip       | realuserid |
# ...

# %% [markdown]
# ## Monthly usage time of learners who have confirmed and are not deleted

# %%
#select('mdl_user')
usage = %sql select id ,firstaccess, lastaccess from mdl_user where confirmed = 1
usage
dta = pd.DataFrame(usage)
# Out:
# * postgresql://postgres:***@localhost/moodle
# 1052 rows affected.

# %%
for row in dta.head(10):
    time = time.fromtimestamp(dta[1])
    print(time)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-c4eba774a99f> in <module>
#       1 for row in dta.head(10):
# ----> 2     time = time.fromtimestamp(dta[1])
#       3     print(time)
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>
